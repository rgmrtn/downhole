# %%
class DownholeSurvey():
    def __init__(self):
        self.test = 'test'
        self.min_curv = Min_Curv(self)
        
class Min_Curv():
    def __init__(self, DownholeSurvey):
        self.data = DownholeSurvey.test

# %%
ds = DownholeSurvey()
ds.min_curv.data
# Out:
# 'test'

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from math import sqrt

# %%
A = [0,1,5]
B = [2,-1,-1]
x = list(zip(A,B))[0]
y = list(zip(A,B))[1]
z = list(zip(A,B))[2]


print(d)

xs = []
ys = []
zs = []
for i in range(int(d)):
    along = i+1
    u = along / d
    xnew = (1-u)* A[0] + (u*B[0])
    ynew = (1-u)* A[1] + (u*B[1])
    znew = (1-u)* A[2] + (u*B[2])
    xs.append(xnew)
    ys.append(ynew)
    zs.append(znew)


fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.plot(x,y,z)
ax.scatter(x,y,z)
ax.scatter(xs, ys, zs)
# Out:
# 6.6332495807108
